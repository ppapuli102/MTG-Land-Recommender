# %% [markdown]
# # Web Scrape MtG Decks and Store them in Dataframe using Beautiful Soup

# %% [markdown]
# | data             | % of total | Description |
# |------------------|:----------:|:---------|
# | training         | 60         | Data used to tune model parameters $w$ and $b$ in training or fitting |
# | cross-validation | 20         | Data used to tune other model parameters like degree of polynomial, regularization or the architecture of a neural network.|
# | test             | 20         | Data used to test the model after tuning to gauge performance on new data |

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests

# %%
URL = "https://www.mtgtop8.com/format?f=ST&meta=58&a="
page = requests.get(URL)

soup = bs(page.content, "html.parser")

print(page.text)
# Out:
# 	<!DOCTYPE HTML>
# 	<html lang="en">
#
# <head>
# <title>Standard events and metagame @ mtgtop8.com</title>
# <link rel="icon" type="image/png" href="https://www.mtgtop8.com/graph/favicon.png">
# <link href="/styles.css" rel="stylesheet" type="text/css">
#
#
#
#
# <script>
#
# var x
# var y
#
# function MAJCoords(evt){
# 	x=evt.clientX
# 	y=evt.clientY
# 	return false;
# }
#
#
# function AffOther(pref){
# 	odel=document.getElementById("other_div");
# 	var r = odel.getBoundingClientRect();
#
# 	if (document.documentElement && document.documentElement.scrollTop) {theTop = document.documentElement.scrollTop;}
# 	else if (document.body) {theTop = document.body.scrollTop;}
#
# 	if(document.getElementById("other_tooltip").style.visibility=="visible"){
# 		document.getElementById('other_tooltip').style.visibility="hidden";
# 	}
# 	else {
# 		document.getElementById("other_tooltip").style.width=(r.right-r.left+80)+"px";
# 		document.getElementById("other_tooltip").style.left=(r.left-40)+"px";
# 		document.getElementById("other_tooltip").style.top=(theTop+r.top+30)+"px";
# 		document.getElementById("other_tooltip").style.visibility="visible";
# 	}
#
# }
#
# function EffOther(){document.getElementById('other_tooltip').style.visibility="hidden";}
#
# </script>
# </head>
# 	<body >
# 	<div align=center class=page>
# 	<div style="max-width:1280px;" valign=top>
# <div id=other_tooltip style="visibility:hidden;width:200px;z-index:10;position: absolute;box-shadow: 0px 10px 10px #666666;padding:2px;background:white;border: 1px white solid;">
#
# 	<div id=other_tooltip_content style="padding:3px;" align=center>
# 	<div style="padding-bottom:15px;"><div  style="position:relative;"><a class=menu_item href=/format?f=ALCH>ALCHEMY</a></div></div>
# 	<div style="padding-bottom:15px;"><div  style="position:relative;"><a class=menu_item href=/format?f=PEA>PEASANT</a></div></div>
# 	<div style="padding-bottom:15px;"><div  style="position:relative;"><a class=menu_item href=/format?f=BL>BLOCK</a></div></div>
# 	<div style="padding-bottom:15px;"><div  style="position:relative;"><a class=menu_item href=/format?f=EX>EXTENDED</a></div></div>
# 	<div style="padding-bottom:15px;"><div  style="position:relative;"><a class=menu_item href=/format?f=HIGH>HIGHLANDER</a></div></div>
# 	<div style="padding-bottom:15px;"><div  style="position:relative;"><a class=menu_item href=/format?f=CHL>CANADIAN HIGHLANDER</a></div></div>
# 	<div onclick="EffOther();" style="cursor:pointer;" class=S12>close</div>
# 	</div>
#
# </div>
# <div style="border:1px:black solid;display:flex;justify-content:space-evenly;align-items:center;flex-wrap:wrap;">
#   <div>
#     <div><a href=/index><img style="width:250px;" src=/graph/title.png></a></div>
#     <div class=G16 style="margin-top:5px;">netdecking with the stars</div>
#   </div>
#     </td>
#     <div>
#       <div style="width:728px;height:90px;overflow:hidden;"></div></td>
#   </div>
# </div>
#
# <div style="position:relative;">
# <div style="margin:5px 0px 5px 0px;display:flex;justify-content:space-evenly;align-items:center;">
# <div style="position:relative;width:160px;"><a class=menu_item_chosen href=/format?f=ST>STANDARD<div class=c_tl></div><div class=c_tr></div><div class=c_bl></div><div class=c_br></div></a></div><div  style="position:relative;width:160px;"><a class=menu_item href=/format?f=PI>PIONEER</a></div><div  style="position:relative;width:160px;"><a class=menu_item href=/format?f=MO>MODERN</a></div><div  style="position:relative;width:160px;"><a class=menu_item href=/format?f=LE>LEGACY</a></div><div  style="position:relative;width:160px;"><a class=menu_item href=/format?f=HI>HISTORIC</a></div><div  style="position:relative;width:160px;"><a class=menu_item href=/format?f=EXP>EXPLORER</a></div><div  style="position:relative;width:160px;"><a class=menu_item href=search>SEARCH</a></div>
# </div>
# <div style="margin:0px 0px 5px 0px;display:flex;justify-content:space-evenly;align-items:center;">
# <div  style="position:relative;width:160px;"><a class=menu_item href=/format?f=VI>VINTAGE</a></div><div  style="position:relative;width:160px;"><a class=menu_item href=/format?f=PAU>PAUPER</a></div><div  style="position:relative;width:160px;"><a class=menu_item href=/format?f=cEDH>cEDH</a></div><div  style="position:relative;width:160px;"><a class=menu_item_14 href=/format?f=EDH>DUEL COMMANDER</a></div><div  style="position:relative;width:160px;"><a class=menu_item href=format_limited>LIMITED</a><img style="display:inline-block;height:17px;vertical-align:-15%;" src=/graph/symbols/one-c.png></div><div id=other_div onclick="AffOther('');" style="cursor:pointer;width:160px;"><a class=menu_item>OTHER</a></div><div  style="position:relative;width:160px;"><a class=menu_item href=submit>SUBMIT</a></div>
# </div>
# <div style="position:absolute;top:8px;right:180px;display:block;"><img src=/graph/star.png></div><div style="position:absolute;top:37px;right:180px;display:block;"><img src=/graph/star.png></div>
# </div>
# <script>
#
#
#
# function PageSubmit(id) {
# 	document.format_form["cp"].value=id;
# 	document.format_form.submit();
# }
#
# function ToggleMetaList(){
# 	if(document.getElementById("metas_list").style.maxHeight=="0px"){
# 		document.getElementById("metas_list").style.maxHeight="600px";
# 		document.getElementById("expand_img").src="/graph/shrink.png";
# 	}
# 	else{
# 		document.getElementById("metas_list").style.maxHeight="0px";
# 		document.getElementById("expand_img").src="/graph/expand.png";
# 	}
# }
#
# function RequestContent(my_url,my_dest) {
# var xhr_object = null;
#
# if(window.XMLHttpRequest) // Firefox
#    xhr_object = new XMLHttpRequest();
# else if(window.ActiveXObject) // Internet Explorer
#    xhr_object = new ActiveXObject("Microsoft.XMLHTTP");
#
#
# xhr_object.open("POST", my_url, true);
#
# xhr_object.onreadystatechange = function() {
#    if(xhr_object.readyState == 4) document.getElementById(my_dest).innerHTML=xhr_object.responseText;
# }
#
# xhr_object.send(null);
# }
#
#
#
# </script>
# <table border=0 width=100%>
#   <tr>
#     <td valign=top width=40%>
# 	<div class=w_title align=center>METAGAME BREAKDOWN<div class=c_tl></div><div class=c_tr></div><div class=c_bl></div><div class=c_br></div></div>
# 	<div align=center>
# 		<div style="position:relative;width:90%;margin:5px;">
%</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/1320.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=1320&meta=58&f=ST>Angels</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>0.1 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/blank.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=143&meta=58&f=ST>Kuldotha Red </a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>0.1 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/blank.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=768&meta=58&f=ST>Merfolk</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>0.1 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/blank.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=266&meta=58&f=ST>UWR Delver</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>0.1 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/blank.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=484&meta=58&f=ST>UR Artifacts</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>0.1 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/blank.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=176&meta=58&f=ST>Puresteel Paladin </a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>0.1 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/52.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=52&meta=58&f=ST>Other - Aggro</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>0.4 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 		  <div class=meta_arch align=center style="margin:10px;">CONTROL 36%</div>
#
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/197.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=197&meta=58&f=ST>Esper Control</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>3 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/463.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=463&meta=58&f=ST>Sultai Control</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>3 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/13.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=13&meta=58&f=ST>Dimir Control</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>3 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/9.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=9&meta=58&f=ST>UW Control</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>3 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/272.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=272&meta=58&f=ST>Jund</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>2 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/808.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=808&meta=58&f=ST>Temur Control</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>2 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/273.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=273&meta=58&f=ST>Bant Control</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>2 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/blank.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=850&meta=58&f=ST>Fires of Invention</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>2 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/15.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=15&meta=58&f=ST>Izzet Control</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>2 %</div>
# 				        <div style="display:inline-block;width:48%;" class=S14></div>
# 				      </div>
# 				    </div>
# 				  </div>
# 				</div>
# 				<div style="display:inline-block;width:48%;" class=hover_tr>
# 				  <div style="display:flex;">
# 				    <div style="width:80px;height:40px;background:black;"><img src=/metas_thumbs/blank.jpg></div>
# 				    <div align=center style="width:100%;">
# 				      <div class=S14><a href=archetype?a=335&meta=58&f=ST>Green Ramp</a></div>
# 				      <div>
#
# 				        <div style="display:inline-block;width:48%;" class=S14>1 %</div>
# ...
# 		  <td width=13% align=center><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>11/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/mtga.png height=14></td>
# 		  <td width=70% class=S14><a href=event?e=41282&f=ST>Perla Negra Series #6</a> @ <a class=und href=event?e=41282&f=ST>MTGADAILYCHALLENGE</a> <span class=new>NEW</span></td>
# 		  <td width=13% align=center><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>10/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/mtgo.png height=14></td>
# 		  <td width=70% class=S14><a href=event?e=41250&f=ST>MTGO League</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>09/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/paper.png height=17></td>
# 		  <td width=70% class=S14><a href=event?e=41215&f=ST>Daily Tournaments</a> @ <a class=und href=event?e=41215&f=ST>Hareruya (Japan)</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>06/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/mtgo.png height=14></td>
# 		  <td width=70% class=S14><a href=event?e=41193&f=ST>MTGO League</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>06/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/paper.png height=17></td>
# 		  <td width=70% class=S14><a href=event?e=41217&f=ST>Store Champions Cup Cycle 2 Qualifier</a> @ <a class=und href=event?e=41217&f=ST>Card Box (Osaka, Japan)</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>05/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/paper.png height=17></td>
# 		  <td width=70% class=S14><a href=event?e=41212&f=ST>Environmental First Battle</a> @ <a class=und href=event?e=41212&f=ST>Hareruya (Nagoya, Japan)</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>05/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/mtgo.png height=14></td>
# 		  <td width=70% class=S14><a href=event?e=41186&f=ST>MTGO Challenge</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>05/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/paper.png height=17></td>
# 		  <td width=70% class=S14><a href=event?e=41216&f=ST>Store Champions Cup Cycle 2 Qualifier</a> @ <a class=und href=event?e=41216&f=ST>Card Box Tsu (Japan)</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>04/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/mtgo.png height=14></td>
# 		  <td width=70% class=S14><a href=event?e=41155&f=ST>MTGO Challenge</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>04/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/paper.png height=17></td>
# 		  <td width=70% class=S14><a href=event?e=41136&f=ST>League Final</a> @ <a class=und href=event?e=41136&f=ST>Club Another World (Russia)</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>04/02/23</td>
# 		</tr>
# 		<tr class=hover_tr>
# 		  <td width=5% align=center><img src=/graph/online/paper.png height=17></td>
# 		  <td width=70% class=S14><a href=event?e=41134&f=ST>Perla Negra Series #5 Rapsolo's Community</a> @ <a class=und href=event?e=41134&f=ST>MTGADailyChallenge</a></td>
# 		  <td width=13% align=center><img src=/graph/star.png><img src=/graph/star.png></td>
# 		  <td align=right width=12% class=S12>03/02/23</td>
# 		</tr>
# 		</table>
#       <div style="display:flex;justify-content:center;margin:5px;"><div class=Nav_PN_no>Prev</div><div class=Nav_cur>1</div><div class=Nav_norm><a href=?f=ST&meta=58&cp=2>2</a></div><div class=Nav_norm><a href=?f=ST&meta=58&cp=3>3</a></div><div class=Nav_norm><a href=?f=ST&meta=58&cp=4>4</a></div><div class=Nav_norm><a href=?f=ST&meta=58&cp=2>Next</a></div></div>
#
# 	<div class=w_title align=center>MOST PLAYED CARDS<div class=c_tl></div><div class=c_tr></div><div class=c_bl></div><div class=c_br></div></div>
#
# 	 <div align=center style="margin: 5px 0px 5px 0px;">
# 	   <a target=_blank href=https://www.mtgpics.com/card?ref=m21246><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">19 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/m21/246.jpg></td></tr>
# 			</table>
# 			</div></a><a target=_blank href=https://www.mtgpics.com/card?ref=rna251><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">10 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/rna/251.jpg></td></tr>
# 			</table>
# 			</div></a><a target=_blank href=https://www.mtgpics.com/card?ref=eld115><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">9 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/eld/115.jpg></td></tr>
# 			</table>
# 			</div></a><a target=_blank href=https://www.mtgpics.com/card?ref=xln254><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">9 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/xln/254.jpg></td></tr>
# 			</table>
# 			</div></a><a target=_blank href=https://www.mtgpics.com/card?ref=rna246><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">8 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/rna/246.jpg></td></tr>
# 			</table>
# 			</div></a><a target=_blank href=https://www.mtgpics.com/card?ref=rna259><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">8 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/rna/259.jpg></td></tr>
# 			</table>
# 			</div></a><a target=_blank href=https://www.mtgpics.com/card?ref=dmu058><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">8 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/dmu/058.jpg></td></tr>
# 			</table>
# 			</div></a><a target=_blank href=https://www.mtgpics.com/card?ref=grn253><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">7 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/grn/253.jpg></td></tr>
# 			</table>
# 			</div></a><a target=_blank href=https://www.mtgpics.com/card?ref=grn258><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">7 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/grn/258.jpg></td></tr>
# 			</table>
# 			</div></a><a target=_blank href=https://www.mtgpics.com/card?ref=kld242><div style="display:inline-block;vertical-align:bottom;padding:2px;position:relative;">
# 			  <div class=most_perc align=center style="position:absolute;bottom:30px;left:60px;">7 %</div>
# 			  <table width=147 height=205 border=0 cellspacing=0 cellpadding=0 style="border-radius:6px;background:black;border:1px black solid;">
# 			  <tr><td align=center valign=middle><img style="display:block;width:134px;height:191px;" src=/pics/kld/242.jpg></td></tr>
# 			</table>
# 			</div></a>
# 	   <div>
# 	     <a href=topcards?f=ST&meta=58>Would you like to know more ?</a> (now with awesome filtering options.)
# 	  </div>
# 	</div>
#
# 	<div class=w_title align=center>RELATED LINKS<div class=c_tl></div><div class=c_tr></div><div class=c_bl></div><div class=c_br></div></div>
# 	<div style="margin-top:5px;display:flex;justify-content:space-around;"><div class=S14><a target=_blank href=https://magic.wizards.com/en/content/standard-formats-magic-gathering>Standard Construction Rules</a></div><div align=center><div class=S14><a href=event?e=40999&f=ST>The Decks to Beat - January '23</a></div><div><select name=archive_d2b onchange="window.open(this.value,'_top')"><option value="">Decks to beat archives</option><option value="event?e=40234&f=ST">The Decks to Beat - December '22</option><option value="event?e=39654&f=ST">The Decks to Beat - November '22</option><option value="event?e=39095&f=ST">The Decks to Beat - October '22</option><option value="event?e=38580&f=ST">The Decks to Beat - September '22</option><option value="event?e=38039&f=ST">The Decks to Beat - August '22</option><option value="event?e=37029&f=ST">The Decks to Beat - June '22</option><option value="event?e=36445&f=ST">The Decks to Beat - May '22</option><option value="event?e=35894&f=ST">The Decks to Beat - April '22</option><option value="event?e=35417&f=ST">The Decks to Beat - March '22</option><option value="event?e=34822&f=ST">The Decks to Beat - February '22</option><option value="event?e=34360&f=ST">The Decks to Beat - January '22</option><option value="event?e=33978&f=ST">The Decks to Beat - December '21</option><option value="event?e=33473&f=ST">The Decks to Beat - November '21</option><option value="event?e=32960&f=ST">The Decks to Beat - October '21</option><option value="event?e=32595&f=ST">The Decks to Beat - September '21</option><option value="event?e=32065&f=ST">The Decks to Beat - August '21</option><option value="event?e=31728&f=ST">The Decks to Beat - July '21</option><option value="event?e=31239&f=ST">The Decks to Beat - June '21</option><option value="event?e=30847&f=ST">The Decks to Beat - May '21</option><option value="event?e=30361&f=ST">The Decks to Beat - April '21</option><option value="event?e=29804&f=ST">The Decks to Beat - March '21</option><option value="event?e=29359&f=ST">The Decks to Beat - February '21</option><option value="event?e=28982&f=ST">The Decks to Beat - January '21</option><option value="event?e=28652&f=ST">The Decks to Beat - December '20</option><option value="event?e=28310&f=ST">The Decks to Beat - November '20</option><option value="event?e=27911&f=ST">The Decks to Beat - October '20</option><option value="event?e=27524&f=ST">The Decks to Beat - September '20</option><option value="event?e=27060&f=ST">The Decks to Beat - August '20</option><option value="event?e=26638&f=ST">The Decks to Beat - July '20</option><option value="event?e=26230&f=ST">The Decks to Beat - June '20</option><option value="event?e=25854&f=ST">The Decks to Beat - May '20</option><option value="event?e=25448&f=ST">The Decks to Beat - April '20</option><option value="event?e=25040&f=ST">The Decks to Beat - March '20</option><option value="event?e=24774&f=ST">The Decks to Beat - February '20</option><option value="event?e=24422&f=ST">The Decks to Beat - January '20</option><option value="event?e=24078&f=ST">The Decks to Beat - December '19</option><option value="event?e=23761&f=ST">The Decks to Beat - November '19</option><option value="event?e=23490&f=ST">The Decks to Beat - October '19</option><option value="event?e=23217&f=ST">The Decks to Beat - September '19</option><option value="event?e=22857&f=ST">The Decks to Beat - August '19</option><option value="event?e=22587&f=ST">The Decks to Beat - July '19</option><option value="event?e=22278&f=ST">The Decks to Beat - June '19</option><option value="event?e=22033&f=ST">The Decks to Beat - May '19</option><option value="event?e=21742&f=ST">The Decks to Beat - April '19</option><option value="event?e=21453&f=ST">The Decks to Beat - March '19</option><option value="event?e=21182&f=ST">The Decks to Beat - February '19</option><option value="event?e=20988&f=ST">The Decks to Beat - January '19</option><option value="event?e=20785&f=ST">The Decks to Beat - December '18</option ...
#     </td>
#   </tr>
# </table>
# <div class=w_title style="margin-top:20px;">
# <div align=center>
# <a class=white href=/privacy>Privacy Policy</a>
#
# <div style="padding:5px;" valign=top class=W10 align=center>
# The information presented on this site about Magic: The Gathering, both literal and graphical, is copyrighted by Wizards of the Coast.
# This website is not produced, endorsed, supported, or affiliated with Wizards of the Coast..
# <div class=c_tl></div><div class=c_tr></div><div class=c_bl></div><div class=c_br></div>
# </div>
# </div>
# </div>
#
# <div id=tag_box style="display:none;"></div>
# <div id=cookie_window class=cookie_banner >
# <div class=S16 style="flex-basis:80%;">
# This site uses cookies for analytics, ads and personalized content. By continuing to browse this site, you agree to this use as described in our <a class=white href=/privacy>Privacy Policy</a> in detail.
#   </div>
# <div class=S16 style="flex-basis:20%;" class=S16><button style="width:80px;font-size : 16px;" onclick="CookieOK();">OK</button></div>
# </div>
# <script>
#
# function CookieOK(){
#   document.getElementById("cookie_window").style.display="none";
#   setCookie("cookieSeen","shown",60);
#   //TagOK();
# }
#
# function setCookie(name,value,days) {
#     var expires = "";
#     if (days) {
#         var date = new Date();
#         date.setTime(date.getTime() + (days*24*60*60*1000));
#         expires = "; expires=" + date.toUTCString();
#     }
#
#     document.cookie = name + "=" + (value || "")  + expires + "; path=/";
#
# }
#
#
# </script></div>
# 	</div></body>
# 	</html>
